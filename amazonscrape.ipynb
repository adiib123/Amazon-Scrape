# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from time import sleep

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:94.0) Gecko/20100101 Firefox/94.0',
    'Accept-Language': 'en-US, en;q=0.5'
}

search_query = 'puma'.replace(' ', '+')
base_url = 'https://www.amazon.com/s?k={0}'.format(search_query)

items = []
for i in range(1, 51):
    print('Processing {0}...'.format(base_url + '&page={0}'.format(i)))
    response = requests.get(base_url + '&page={0}'.format(i), headers=headers)
    soup = BeautifulSoup(response.content, 'html.parser')
    
    results = soup.find_all('div', {'class': 's-result-item', 'data-component-type': 's-search-result'})

    for result in results:
        product_name = result.h2.text

        try:
            rating = result.find('i', {'class': 'a-icon'}).text
            rating_count = result.find_all('span', {'aria-label': True})[1].text
        except AttributeError:
            continue

        try:
            price1 = result.find('span', {'class': 'a-price-whole'}).text
            price2 = result.find('span', {'class': 'a-price-fraction'}).text
            price = float(price1 + price2)
            product_url = 'https://amazon.com' + result.h2.a['href']
            # print(rating_count, product_url)
            items.append([product_name, rating, rating_count, price, product_url])
        except AttributeError:
            continue
    sleep(1.5)
    
df = pd.DataFrame(items, columns=['product', 'rating', 'rating count', 'price', 'product url'])
df.to_csv('{0}.csv'.format(search_query), index=False)
# Out:
# Processing https://www.amazon.com/s?k=puma&page=1...
# Processing https://www.amazon.com/s?k=puma&page=2...
# Processing https://www.amazon.com/s?k=puma&page=3...
# Processing https://www.amazon.com/s?k=puma&page=4...
# Processing https://www.amazon.com/s?k=puma&page=5...
# Processing https://www.amazon.com/s?k=puma&page=6...
# Processing https://www.amazon.com/s?k=puma&page=7...
# Processing https://www.amazon.com/s?k=puma&page=8...
# Processing https://www.amazon.com/s?k=puma&page=9...
# Processing https://www.amazon.com/s?k=puma&page=10...
# Processing https://www.amazon.com/s?k=puma&page=11...
# Processing https://www.amazon.com/s?k=puma&page=12...
# Processing https://www.amazon.com/s?k=puma&page=13...
# Processing https://www.amazon.com/s?k=puma&page=14...
# Processing https://www.amazon.com/s?k=puma&page=15...
# Processing https://www.amazon.com/s?k=puma&page=16...
# Processing https://www.amazon.com/s?k=puma&page=17...
# Processing https://www.amazon.com/s?k=puma&page=18...
# Processing https://www.amazon.com/s?k=puma&page=19...
# Processing https://www.amazon.com/s?k=puma&page=20...
# Processing https://www.amazon.com/s?k=puma&page=21...
# Processing https://www.amazon.com/s?k=puma&page=22...
# Processing https://www.amazon.com/s?k=puma&page=23...
# Processing https://www.amazon.com/s?k=puma&page=24...
# Processing https://www.amazon.com/s?k=puma&page=25...
# Processing https://www.amazon.com/s?k=puma&page=26...
# Processing https://www.amazon.com/s?k=puma&page=27...
# Processing https://www.amazon.com/s?k=puma&page=28...
# Processing https://www.amazon.com/s?k=puma&page=29...
# Processing https://www.amazon.com/s?k=puma&page=30...
# Processing https://www.amazon.com/s?k=puma&page=31...
# Processing https://www.amazon.com/s?k=puma&page=32...
# Processing https://www.amazon.com/s?k=puma&page=33...
# Processing https://www.amazon.com/s?k=puma&page=34...
# Processing https://www.amazon.com/s?k=puma&page=35...
# Processing https://www.amazon.com/s?k=puma&page=36...
# Processing https://www.amazon.com/s?k=puma&page=37...
# Processing https://www.amazon.com/s?k=puma&page=38...
# Processing https://www.amazon.com/s?k=puma&page=39...
# Processing https://www.amazon.com/s?k=puma&page=40...
# Processing https://www.amazon.com/s?k=puma&page=41...
# Processing https://www.amazon.com/s?k=puma&page=42...
# Processing https://www.amazon.com/s?k=puma&page=43...
# Processing https://www.amazon.com/s?k=puma&page=44...
# Processing https://www.amazon.com/s?k=puma&page=45...
# Processing https://www.amazon.com/s?k=puma&page=46...
# Processing https://www.amazon.com/s?k=puma&page=47...
# Processing https://www.amazon.com/s?k=puma&page=48...
# Processing https://www.amazon.com/s?k=puma&page=49...
# Processing https://www.amazon.com/s?k=puma&page=50...
